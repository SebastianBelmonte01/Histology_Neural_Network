# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianBelmonte01/Histology_Neural_Network/blob/main/BelmonteSebastian_Desafio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colorectal histology dataset with LeNet 5

# %% [markdown]
# # Preview: Neural Network examples with `tf.keras`
#
# - `tf.keras` Software (http://keras.io/);
#
# - Visual example of LeNet-5 (http://yann.lecun.com/exdb/lenet/) using MNIST digits dataset;
#
# - Examples with common neural network topologies (https://machinelearningmastery.com/tensorflow-tutorial-deep-learning-with-tf-keras/).

# %% [markdown]
# ## Colorectal histology
#
# Methods to diagnose colorectal using histology images (<https://zenodo.org/record/53169#.XGZemKwzbmG>, <https://www.tensorflow.org/datasets/catalog/colorectal_histology>)
#
# In this case, the purpose is to classify the type of histology in a given image in the following categories:
#
# - 0: TUMOR
# - 1: STROMA
# - 2: COMPLEX
# - 3: LYMPHO
# - 4: DEBRIS
# - 5: MUCOSA
# - 6: ADIPOSE
# - 7: EMPTY

# %% [markdown]
# ## Local instalation (option 1)

# %% [markdown]
# Install the following Python packages to run this notebook

# %% [markdown]
# `pip install pip -U`
#
# `pip install tensorflow jupyter`

# %% [markdown]
# ## Google Colab (option 2)

# %% [markdown]
# [Google Colab](https://colab.research.google.com/) is a research project created to help disseminate machine learning education and research. It's a `Jupyter notebook` environment that requires no setup to use and runs entirely in the cloud.
#
# Colaboratory notebooks are stored in [Google Drive](https://drive.google.com) and can be shared just as you would with Google Docs or Sheets. Colaboratory is free to use.
#
# For more information, see our [FAQ](https://research.google.com/colaboratory/faq.html).

# %% [markdown]
# ### How install extra packages
# Google Colab installs a series of basic packages if we need any additional package just install it.

# %%
#!pip install scikit-learn -U

#Strtifiedkfold

# %% [markdown]
# ## Import packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import sklearn
from sklearn.model_selection import train_test_split
from sklearn import metrics

import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ## Define global constants

# %% [markdown]
# Lets start with a few epochs to test learning network parameters

# %%
batch_size = 32 #tamaño del conjunto cada cuantos se deben mirar para despues actualizar los pesos
nb_classes = 2  #or 8
epochs = 25

# Scaling input image to theses dimensions
img_rows, img_cols = 32, 32

# %% [markdown]
# ## Load image database

# %%
def format_example(image):
    image = tf.cast(image, tf.float32)
    # Normalize the pixel values
    image = image / 255.0
    # Resize the image
    image = tf.image.resize(image, (img_rows, img_cols))
    return image


def load_data(name="colorectal_histology"):
  train_ds = tfds.load(name, split=tfds.Split.TRAIN, batch_size=-1)
  train_ds['image'] = tf.map_fn(format_example, train_ds['image'], dtype=tf.float32)
  numpy_ds = tfds.as_numpy(train_ds)
  X, y = numpy_ds['image'], numpy_ds['label']

  return np.array(X), np.array(y)

# %% [markdown]
# ## Plot images

# %%
def plot_symbols(X,y,n=15):
    index = np.random.randint(len(y), size=n)
    plt.figure(figsize=(25, 2))
    for i in np.arange(n):
        ax = plt.subplot(1,n,i+1)
        plt.imshow(X[index[i],:,:,:])
        plt.gray()
        ax.set_title(f'{y[index[i]]}-{index[i]}')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %% [markdown]
# ## Build LeNet5 structure
#
# <center><img src="https://www.dlsi.ua.es/~juanra/UA/curso_verano_DL/images/LeNet5.jpg"></center>

# %%
#
# Build an ANN structure - LeNet5
#

def cnn_model():
    #
    # Neural Network Structure
    #
    
    model = Sequential()
    
    model.add(layers.Conv2D(6, (5, 5)))
    #model.add(layers.Activation("relu"))
    model.add(layers.Activation("sigmoid"))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    
    model.add(layers.Conv2D(16, (5, 5)))
    #model.add(layers.Activation("relu"))
    model.add(layers.Activation("sigmoid"))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
        
    model.add(layers.Flatten())
    
    model.add(layers.Dense(120))
    #model.add(layers.Activation("relu"))
    model.add(layers.Activation("sigmoid"))

    model.add(layers.Dense(84))
    #model.add(layers.Activation("relu"))
    model.add(layers.Activation("sigmoid"))
    
    model.add(layers.Dense(nb_classes))
    #Tiene que ser la ultima porque es la que potencia la salida
    model.add(layers.Activation('softmax'))

    return model

# %% [markdown]
# ## **Models Implemented by Sebastian Belmonte**
#
# ---
# For image classification we are going to usea a convolutional neural network where it has convolutions (hidden layers, filters, etc), pooling where it reduces data in small segments.

# %%
def cnn_model_2d():
  model = tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(
          32, (5, 5), activation ="relu", input_shape(32, 32, 1)
      ),

      tf.keras.layers.MaxPooling2D(pool_size=(2,2)),

      tf.keras.layers.Flatten(), 

      #Addind hidden layers
      tf.keras.layers.Dense(128, activation="relu"),
      tf.keras.layers.Dropout(0.5),

      #Adding an output for all 8 cancer types
      tf.keras.layers.Dense(8, activation="softmax")

  ])
  return model

# %% [markdown]
# ## Start to run the program

# %% [markdown]
# ### Load data

# %%
##################################################################################
# Main program

X, y = load_data()

print(X.shape, 'train samples')
print(img_rows,'x', img_cols, 'image size')
print(epochs,'epochs')
# Out:
# (5000, 32, 32, 3) train samples
# 32 x 32 image size
# 25 epochs

# %% [markdown]
# Only for binary classification. All number of classes greater than 0 will be set to 1.

# %%
if nb_classes==2: #Quiere decir si hay dos clases
  y[y>0] = 1 #Los que son otra cosa se les asigna el valor de uno

# %% [markdown]
# ### Let to see examples of the dataset

# %%
plot_symbols(X, y, 15)

# %% [markdown]
# ## Number of examples per class

# %%
pd.DataFrame({'ncount':pd.Series(y).value_counts(), '% ncount':pd.Series(y).value_counts(normalize=True)*100})
# Out:
#    ncount  % ncount
# 1    4375      87.5
# 0     625      12.5

# %% [markdown]
# ## Split examples in training/test sets

# %% [markdown]
# This section is introductory to serve as a simple example. To test the model created in different situations, a 10 cross validation (10-CV) strategy should be used.

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

#print(f'X_train {X_train.shape} X_test {X_test.shape}')
#print(f'y_train {y_train.shape} y_test {y_test.shape}')

skf = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)
skf.get_n_splits(X, y)
print(skf)

for train_index, test_index in skf.split(X, y):
  #print("Train: ", train_index, " Test: ", test_index)
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]



print(f'X_train {X_train.shape} X_test {X_test.shape}')
print(f'y_train {y_train.shape} y_test {y_test.shape}')
# Out:
# StratifiedKFold(n_splits=10, random_state=42, shuffle=True)
# X_train (4500, 32, 32, 3) X_test (500, 32, 32, 3)
# y_train (4500,) y_test (500,)

# %% [markdown]
# ### Model and optimizers

# %% [markdown]
# Test [optimizer](https://keras.io/optimizers/) parameter with `sgd`, `adadelta` or `adam` values in order to check the final precision achieved.

# %%
#model = cnn_model()
model = cnn_model_2d

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam', 
    metrics=['accuracy']
)

#early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1, verbose=2) #, callbacks=[early_stopping])

print(model.summary())
# Out:
# Epoch 1/25
# 127/127 - 1s - loss: 0.3528 - accuracy: 0.8790 - val_loss: 0.3410 - val_accuracy: 0.8400 - 1s/epoch - 9ms/step
# Epoch 2/25
# 127/127 - 0s - loss: 0.2791 - accuracy: 0.8681 - val_loss: 0.3142 - val_accuracy: 0.8111 - 427ms/epoch - 3ms/step
# Epoch 3/25
# 127/127 - 0s - loss: 0.2697 - accuracy: 0.8672 - val_loss: 0.3023 - val_accuracy: 0.8133 - 419ms/epoch - 3ms/step
# Epoch 4/25
# 127/127 - 0s - loss: 0.2605 - accuracy: 0.8575 - val_loss: 0.2980 - val_accuracy: 0.8200 - 412ms/epoch - 3ms/step
# Epoch 5/25
# 127/127 - 0s - loss: 0.2593 - accuracy: 0.8672 - val_loss: 0.2953 - val_accuracy: 0.8178 - 412ms/epoch - 3ms/step
# Epoch 6/25
# 127/127 - 0s - loss: 0.2532 - accuracy: 0.8662 - val_loss: 0.2936 - val_accuracy: 0.8244 - 446ms/epoch - 4ms/step
# Epoch 7/25
# 127/127 - 0s - loss: 0.2505 - accuracy: 0.8654 - val_loss: 0.2935 - val_accuracy: 0.8178 - 390ms/epoch - 3ms/step
# Epoch 8/25
# 127/127 - 0s - loss: 0.2524 - accuracy: 0.8640 - val_loss: 0.2878 - val_accuracy: 0.8133 - 422ms/epoch - 3ms/step
# Epoch 9/25
# 127/127 - 0s - loss: 0.2410 - accuracy: 0.8598 - val_loss: 0.2856 - val_accuracy: 0.8178 - 395ms/epoch - 3ms/step
# Epoch 10/25
# 127/127 - 0s - loss: 0.2394 - accuracy: 0.8694 - val_loss: 0.2873 - val_accuracy: 0.8156 - 429ms/epoch - 3ms/step
# Epoch 11/25
# 127/127 - 0s - loss: 0.2338 - accuracy: 0.8699 - val_loss: 0.3105 - val_accuracy: 0.8356 - 419ms/epoch - 3ms/step
# Epoch 12/25
# 127/127 - 0s - loss: 0.2321 - accuracy: 0.8699 - val_loss: 0.2786 - val_accuracy: 0.8311 - 407ms/epoch - 3ms/step
# Epoch 13/25
# 127/127 - 0s - loss: 0.2305 - accuracy: 0.8726 - val_loss: 0.2919 - val_accuracy: 0.8422 - 420ms/epoch - 3ms/step
# Epoch 14/25
# 127/127 - 0s - loss: 0.2278 - accuracy: 0.8758 - val_loss: 0.2785 - val_accuracy: 0.8311 - 411ms/epoch - 3ms/step
# Epoch 15/25
# 127/127 - 0s - loss: 0.2267 - accuracy: 0.8743 - val_loss: 0.2717 - val_accuracy: 0.8378 - 416ms/epoch - 3ms/step
# Epoch 16/25
# 127/127 - 0s - loss: 0.2272 - accuracy: 0.8736 - val_loss: 0.2753 - val_accuracy: 0.8422 - 423ms/epoch - 3ms/step
# Epoch 17/25
# 127/127 - 0s - loss: 0.2185 - accuracy: 0.8756 - val_loss: 0.2975 - val_accuracy: 0.8422 - 412ms/epoch - 3ms/step
# Epoch 18/25
# 127/127 - 0s - loss: 0.2167 - accuracy: 0.8825 - val_loss: 0.2669 - val_accuracy: 0.8378 - 433ms/epoch - 3ms/step
# Epoch 19/25
# 127/127 - 0s - loss: 0.2152 - accuracy: 0.8904 - val_loss: 0.2795 - val_accuracy: 0.8533 - 434ms/epoch - 3ms/step
# Epoch 20/25
# 127/127 - 0s - loss: 0.2116 - accuracy: 0.8869 - val_loss: 0.2613 - val_accuracy: 0.8444 - 414ms/epoch - 3ms/step
# Epoch 21/25
# 127/127 - 0s - loss: 0.2112 - accuracy: 0.8872 - val_loss: 0.2571 - val_accuracy: 0.8422 - 391ms/epoch - 3ms/step
# Epoch 22/25
# 127/127 - 0s - loss: 0.2111 - accuracy: 0.8889 - val_loss: 0.2654 - val_accuracy: 0.8622 - 404ms/epoch - 3ms/step
# Epoch 23/25
# 127/127 - 0s - loss: 0.2092 - accuracy: 0.8926 - val_loss: 0.2828 - val_accuracy: 0.8556 - 446ms/epoch - 4ms/step
# Epoch 24/25
# 127/127 - 0s - loss: 0.2072 - accuracy: 0.8970 - val_loss: 0.2634 - val_accuracy: 0.8667 - 411ms/epoch - 3ms/step
# Epoch 25/25
# 127/127 - 0s - loss: 0.1990 - accuracy: 0.8995 - val_loss: 0.3594 - val_accuracy: 0.8444 - 412ms/epoch - 3ms/step
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 28, 28, 6)         456
#
#  activation_45 (Activation)  (None, 28, 28, 6)         0
#
#  max_pooling2d_18 (MaxPoolin  (None, 14, 14, 6)        0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 10, 10, 16)        2416
#
#  activation_46 (Activation)  (None, 10, 10, 16)        0
#
#  max_pooling2d_19 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 400)               0
#
#  dense_27 (Dense)            (None, 120)               48120
#
#  activation_47 (Activation)  (None, 120)               0
#
#  dense_28 (Dense)            (None, 84)                10164
#
#  activation_48 (Activation)  (None, 84)                0
#
#  dense_29 (Dense)            (None, 2)                 170
#
#  activation_49 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 61,326
# Trainable params: 61,326
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
loss, acc = model.evaluate(X_test, y_test, batch_size=batch_size)
print(f'loss: {loss:.2f} acc: {acc:.2f}')
# Out:
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2832 - accuracy: 0.8760
# loss: 0.28 acc: 0.88

# %%
# Output prediction for the first five X_test images
model.predict(X_test[:5], batch_size=batch_size)
# Out:
# 1/1 [==============================] - 0s 63ms/step
# array([[8.4767240e-04, 9.9915230e-01],
#        [4.2213628e-04, 9.9957782e-01],
#        [6.1587173e-02, 9.3841279e-01],
#        [2.7529770e-01, 7.2470230e-01],
#        [9.9145668e-04, 9.9900860e-01]], dtype=float32)

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Testing AUC result for two and multiple classes

# %% [markdown]
# y_scores = model.predict(X_test) # Confidence prediction per class
# y_pred = y_scores.argmax(axis=1) # Select classes with most confidence prediction
#
# if nb_classes ==  2:
#   print(f'AUC {metrics.roc_auc_score(y_test, np.round(y_scores[:,1],2)):.4f} ')
# else:
#   print(f'AUC {metrics.roc_auc_score(y_test, y_scores, multi_class = "ovr"):.4f} ')

# %% [markdown]
# ## More metrics about results

# %% [markdown]
# We can find more information about `precision`, `recall` and `f1` metrics in <https://en.wikipedia.org/wiki/Precision_and_recall>.

# %%
print('Predictions', pd.Series(y_pred).value_counts(),'\n')

print('Confusion matrix')
print(metrics.confusion_matrix(y_test,y_pred),'\n')

target_names = ['TUMOR', 'HEALTHY'] if nb_classes ==  2 else ['TUMOR','STROMA','COMPLEX','LYMPHO','DEBRIS','MUCOSA','ADIPOSE','EMPTY']

print(metrics.classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Predictions 1    454
# 0     46
# dtype: int64
#
# Confusion matrix
# [[ 39  24]
#  [  7 430]]
#
#               precision    recall  f1-score   support
#
#        TUMOR       0.85      0.62      0.72        63
#      HEALTHY       0.95      0.98      0.97       437
#
#     accuracy                           0.94       500
#    macro avg       0.90      0.80      0.84       500
# weighted avg       0.93      0.94      0.93       500
